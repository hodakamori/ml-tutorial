# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, GATConv, global_mean_pool
from torch_geometric.data import Data, DataLoader
from rdkit import Chem
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
class GCNMoleculeModel(nn.Module):
    def __init__(self, num_node_features):
        super(GCNMoleculeModel, self).__init__()
        self.conv1 = GCNConv(num_node_features, 64)
        self.conv2 = GCNConv(64, 64)
        self.fc = nn.Linear(64, 1)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = global_mean_pool(x, batch)  # Global mean pooling
        x = self.fc(x)
        
        return x.view(-1)

# %%
class ImprovedGCNMoleculeModel(nn.Module):
    def __init__(self, num_node_features):
        super(ImprovedGCNMoleculeModel, self).__init__()
        self.conv1 = GCNConv(num_node_features, 64)
        self.conv2 = GCNConv(64, 128)
        self.conv3 = GATConv(128, 128, heads=4, concat=False)
        self.bn1 = nn.BatchNorm1d(64)
        self.bn2 = nn.BatchNorm1d(128)
        self.bn3 = nn.BatchNorm1d(128)
        self.fc1 = nn.Linear(128, 64)
        self.fc2 = nn.Linear(64, 1)
        self.dropout = nn.Dropout(0.2)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        
        x = F.relu(self.bn1(self.conv1(x, edge_index)))
        x = self.dropout(x)
        x = F.relu(self.bn2(self.conv2(x, edge_index)))
        x = self.dropout(x)
        x = F.relu(self.bn3(self.conv3(x, edge_index)))
        
        x = global_mean_pool(x, batch)  # Global mean pooling
        
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        
        return x.view(-1)

# %%
class MoleculeDataset(torch.utils.data.Dataset):
    def __init__(self, csv_path):
        df = pd.read_csv(csv_path)
        smiles_list = df["smiles"].values
        values = df["logS"].values
        data_list = [
            (self.smiles_to_graph(smiles), torch.tensor([label], dtype=torch.float))
            for smiles, label in zip(smiles_list, values)
        ]
        self.data_list = data_list

    @staticmethod
    def smiles_to_graph(smiles):
        mol = Chem.MolFromSmiles(smiles)
        mol = Chem.AddHs(mol)
        
        node_features = []
        for atom in mol.GetAtoms():
            feature = [
                atom.GetAtomicNum(),
                atom.GetTotalDegree(),
                atom.GetFormalCharge(),
                atom.GetTotalNumHs(),
                int(atom.GetIsAromatic())
            ]
            node_features.append(feature)

        edges = []
        for bond in mol.GetBonds():
            i = bond.GetBeginAtomIdx()
            j = bond.GetEndAtomIdx()
            edges.append([i, j])
            edges.append([j, i])

        x = torch.tensor(node_features, dtype=torch.float)
        edge_index = torch.tensor(edges, dtype=torch.long).t().contiguous()

        return Data(x=x, edge_index=edge_index)

    def __len__(self):
        return len(self.data_list)

    def __getitem__(self, idx):
        return self.data_list[idx]

# %%
dataset = MoleculeDataset(csv_path="../data/delaney-rdkitfp.csv")

# %%
test_size = 0.2
val_size = 0.2
train_val_data, test_data = train_test_split(dataset, test_size=test_size)
train_data, val_data = train_test_split(train_val_data, test_size=val_size/(1-test_size))

# %%
batch_size = 8
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size)
test_loader = DataLoader(test_data, batch_size=batch_size)

loaders = {
    'train': train_loader,
    'val': val_loader,
    'test': test_loader
}

# %%
def train(model, loader, optimizer, device):
    model.train()
    total_loss = 0
    for data, target in loader:
        data = data.to(device)
        target = target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.mse_loss(output, target.squeeze())
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    return total_loss / len(loader.dataset)

# %%
def evaluate(model, loader, device):
    model.eval()
    predictions = []
    targets = []
    total_loss = 0
    with torch.no_grad():
        for data, target in loader:
            data = data.to(device)
            target = target.to(device)
            out = model(data)
            loss = F.mse_loss(out, target.squeeze())
            total_loss += loss.item() * data.num_graphs
            predictions.append(out.cpu())
            targets.append(target.cpu())
    
    predictions = torch.cat(predictions, dim=0).numpy()
    targets = torch.cat(targets, dim=0).numpy()
    avg_loss = total_loss / len(loader.dataset)
    return predictions, targets, avg_loss

# %%
# モデルの初期化
# model = GCNMoleculeModel(num_node_features=5)
model = ImprovedGCNMoleculeModel(num_node_features=5)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()

# %%
# Early stoppingの設定
best_val_loss = float('inf')
patience = 10
counter = 0
num_epochs = 200
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_loss_history = []
val_loss_history = []
for epoch in range(num_epochs):
    train_loss = train(model, train_loader, optimizer, device)
    _, _, val_loss = evaluate(model, val_loader, device)
    train_loss_history.append(train_loss)
    val_loss_history.append(val_loss)
    print(f'Epoch: {epoch+1:03d}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')

    # if val_loss < best_val_loss:
    #     best_val_loss = val_loss
    #     counter = 0
    #     torch.save(model.state_dict(), 'best_model.pth')
    # else:
    #     counter += 1
    #     if counter >= patience:
    #         print("Early stopping")
    #         break

# model.load_state_dict(torch.load('best_model.pth'))
_, _, test_loss = evaluate(model, test_loader, device)
print(f'Test Loss: {test_loss:.4f}')
# Out:
# Epoch: 001, Train Loss: 5.7020, Val Loss: 3.3786
# Epoch: 002, Train Loss: 3.4347, Val Loss: 2.3776
# Epoch: 003, Train Loss: 2.7790, Val Loss: 2.2838
# Epoch: 004, Train Loss: 2.6566, Val Loss: 2.0336
# Epoch: 005, Train Loss: 2.5872, Val Loss: 2.4908
# Epoch: 006, Train Loss: 2.5368, Val Loss: 1.8179
# Epoch: 007, Train Loss: 2.5414, Val Loss: 2.1104
# Epoch: 008, Train Loss: 2.3396, Val Loss: 1.7906
# Epoch: 009, Train Loss: 2.3223, Val Loss: 1.8774
# Epoch: 010, Train Loss: 2.1620, Val Loss: 1.5797
# Epoch: 011, Train Loss: 2.0739, Val Loss: 1.6377
# Epoch: 012, Train Loss: 2.1036, Val Loss: 1.8304
# Epoch: 013, Train Loss: 2.2476, Val Loss: 1.5481
# Epoch: 014, Train Loss: 2.0571, Val Loss: 1.5133
# Epoch: 015, Train Loss: 2.1349, Val Loss: 1.7489
# Epoch: 016, Train Loss: 2.0977, Val Loss: 2.0867
# Epoch: 017, Train Loss: 2.0043, Val Loss: 1.7858
# Epoch: 018, Train Loss: 2.0867, Val Loss: 1.8357
# Epoch: 019, Train Loss: 2.0501, Val Loss: 1.3901
# Epoch: 020, Train Loss: 2.0083, Val Loss: 1.4340
# Epoch: 021, Train Loss: 1.9679, Val Loss: 1.4229
# Epoch: 022, Train Loss: 1.9757, Val Loss: 1.7060
# Epoch: 023, Train Loss: 2.1050, Val Loss: 1.3333
# Epoch: 024, Train Loss: 1.8019, Val Loss: 1.4768
# Epoch: 025, Train Loss: 1.9877, Val Loss: 1.3502
# Epoch: 026, Train Loss: 1.9157, Val Loss: 1.3177
# Epoch: 027, Train Loss: 2.0515, Val Loss: 1.5030
# Epoch: 028, Train Loss: 2.0650, Val Loss: 1.3373
# Epoch: 029, Train Loss: 2.0469, Val Loss: 2.4262
# Epoch: 030, Train Loss: 1.8591, Val Loss: 1.4694
# Epoch: 031, Train Loss: 1.6944, Val Loss: 1.3936
# Epoch: 032, Train Loss: 1.9901, Val Loss: 1.6368
# Epoch: 033, Train Loss: 1.7827, Val Loss: 1.9938
# Epoch: 034, Train Loss: 1.8232, Val Loss: 1.3368
# Epoch: 035, Train Loss: 2.0115, Val Loss: 1.4395
# Epoch: 036, Train Loss: 1.9581, Val Loss: 1.7500
# Epoch: 037, Train Loss: 1.7863, Val Loss: 1.2905
# Epoch: 038, Train Loss: 1.8258, Val Loss: 1.3888
# Epoch: 039, Train Loss: 1.8535, Val Loss: 1.2622
# Epoch: 040, Train Loss: 1.8034, Val Loss: 1.4044
# Epoch: 041, Train Loss: 1.8479, Val Loss: 1.5983
# Epoch: 042, Train Loss: 1.7206, Val Loss: 1.5977
# Epoch: 043, Train Loss: 1.8141, Val Loss: 1.8045
# Epoch: 044, Train Loss: 1.6986, Val Loss: 1.3219
# Epoch: 045, Train Loss: 1.8314, Val Loss: 1.3074
# Epoch: 046, Train Loss: 1.6916, Val Loss: 1.5938
# Epoch: 047, Train Loss: 1.7403, Val Loss: 1.3104
# Epoch: 048, Train Loss: 1.8200, Val Loss: 1.2977
# Epoch: 049, Train Loss: 1.5711, Val Loss: 1.5669
# Epoch: 050, Train Loss: 1.7314, Val Loss: 1.5823
# Epoch: 051, Train Loss: 1.8875, Val Loss: 1.4813
# Epoch: 052, Train Loss: 1.6956, Val Loss: 1.2837
# Epoch: 053, Train Loss: 1.6621, Val Loss: 1.6822
# Epoch: 054, Train Loss: 1.5984, Val Loss: 1.3457
# Epoch: 055, Train Loss: 1.6680, Val Loss: 1.2603
# Epoch: 056, Train Loss: 1.4617, Val Loss: 1.2417
# Epoch: 057, Train Loss: 1.5628, Val Loss: 1.2938
# Epoch: 058, Train Loss: 1.6266, Val Loss: 1.3425
# Epoch: 059, Train Loss: 1.6596, Val Loss: 1.2245
# Epoch: 060, Train Loss: 1.6628, Val Loss: 1.5159
# Epoch: 061, Train Loss: 1.7967, Val Loss: 1.2584
# Epoch: 062, Train Loss: 1.6427, Val Loss: 1.1653
# Epoch: 063, Train Loss: 1.8165, Val Loss: 1.4334
# Epoch: 064, Train Loss: 1.6417, Val Loss: 1.2009
# Epoch: 065, Train Loss: 1.8142, Val Loss: 1.7330
# Epoch: 066, Train Loss: 1.5512, Val Loss: 1.5576
# Epoch: 067, Train Loss: 1.7849, Val Loss: 1.3166
# Epoch: 068, Train Loss: 1.6178, Val Loss: 1.3228
# Epoch: 069, Train Loss: 1.6259, Val Loss: 1.2382
# Epoch: 070, Train Loss: 1.6332, Val Loss: 1.2858
# Epoch: 071, Train Loss: 1.5737, Val Loss: 1.2191
# Epoch: 072, Train Loss: 1.6480, Val Loss: 1.3470
# Epoch: 073, Train Loss: 1.6917, Val Loss: 1.2518
# Epoch: 074, Train Loss: 1.5796, Val Loss: 1.1387
# Epoch: 075, Train Loss: 1.5712, Val Loss: 1.1131
# Epoch: 076, Train Loss: 1.6421, Val Loss: 1.3535
# Epoch: 077, Train Loss: 1.5105, Val Loss: 1.3811
# Epoch: 078, Train Loss: 1.6821, Val Loss: 1.1565
# Epoch: 079, Train Loss: 1.5052, Val Loss: 1.1242
# Epoch: 080, Train Loss: 1.5175, Val Loss: 1.1669
# Epoch: 081, Train Loss: 1.5230, Val Loss: 1.1675
# Epoch: 082, Train Loss: 1.6007, Val Loss: 1.2032
# Epoch: 083, Train Loss: 1.5242, Val Loss: 1.0607
# Epoch: 084, Train Loss: 1.3616, Val Loss: 1.0551
# Epoch: 085, Train Loss: 1.5763, Val Loss: 1.2184
# Epoch: 086, Train Loss: 1.6001, Val Loss: 1.1611
# Epoch: 087, Train Loss: 1.5086, Val Loss: 1.1641
# Epoch: 088, Train Loss: 1.6386, Val Loss: 1.1188
# Epoch: 089, Train Loss: 1.4822, Val Loss: 1.1126
# Epoch: 090, Train Loss: 1.5911, Val Loss: 1.6779
# Epoch: 091, Train Loss: 1.4109, Val Loss: 1.2432
# Epoch: 092, Train Loss: 1.2939, Val Loss: 1.0737
# Epoch: 093, Train Loss: 1.4201, Val Loss: 1.1191
# Epoch: 094, Train Loss: 1.4501, Val Loss: 1.0674
# Epoch: 095, Train Loss: 1.3981, Val Loss: 1.1871
# Epoch: 096, Train Loss: 1.4838, Val Loss: 1.1301
# Epoch: 097, Train Loss: 1.4530, Val Loss: 1.1456
# Epoch: 098, Train Loss: 1.3265, Val Loss: 1.1153
# Epoch: 099, Train Loss: 1.6288, Val Loss: 1.1199
# Epoch: 100, Train Loss: 1.3601, Val Loss: 1.1934
# Epoch: 101, Train Loss: 1.3787, Val Loss: 1.1604
# Epoch: 102, Train Loss: 1.5206, Val Loss: 1.0598
# Epoch: 103, Train Loss: 1.4069, Val Loss: 1.2154
# Epoch: 104, Train Loss: 1.5216, Val Loss: 1.2260
# Epoch: 105, Train Loss: 1.4708, Val Loss: 1.1369
# Epoch: 106, Train Loss: 1.2316, Val Loss: 1.1239
# Epoch: 107, Train Loss: 1.3438, Val Loss: 1.0358
# Epoch: 108, Train Loss: 1.3334, Val Loss: 1.0299
# Epoch: 109, Train Loss: 1.4997, Val Loss: 1.2153
# Epoch: 110, Train Loss: 1.2416, Val Loss: 1.2698
# Epoch: 111, Train Loss: 1.2507, Val Loss: 1.2104
# Epoch: 112, Train Loss: 1.4652, Val Loss: 1.0339
# Epoch: 113, Train Loss: 1.3879, Val Loss: 1.1477
# Epoch: 114, Train Loss: 1.4510, Val Loss: 1.1712
# Epoch: 115, Train Loss: 1.3902, Val Loss: 1.0362
# Epoch: 116, Train Loss: 1.3971, Val Loss: 1.1975
# Epoch: 117, Train Loss: 1.5497, Val Loss: 1.1556
# Epoch: 118, Train Loss: 1.4013, Val Loss: 1.0432
# Epoch: 119, Train Loss: 1.3679, Val Loss: 1.0799
# Epoch: 120, Train Loss: 1.3806, Val Loss: 1.0622
# Epoch: 121, Train Loss: 1.2774, Val Loss: 1.1104
# Epoch: 122, Train Loss: 1.4471, Val Loss: 1.0362
# Epoch: 123, Train Loss: 1.2579, Val Loss: 1.1651
# Epoch: 124, Train Loss: 1.3290, Val Loss: 1.1233
# Epoch: 125, Train Loss: 1.3627, Val Loss: 1.1006
# Epoch: 126, Train Loss: 1.3088, Val Loss: 1.1043
# Epoch: 127, Train Loss: 1.3071, Val Loss: 1.2519
# Epoch: 128, Train Loss: 1.3404, Val Loss: 1.0055
# Epoch: 129, Train Loss: 1.3562, Val Loss: 1.1024
# Epoch: 130, Train Loss: 1.4230, Val Loss: 1.0973
# Epoch: 131, Train Loss: 1.2848, Val Loss: 1.0847
# Epoch: 132, Train Loss: 1.2473, Val Loss: 1.0099
# Epoch: 133, Train Loss: 1.3391, Val Loss: 1.1335
# Epoch: 134, Train Loss: 1.3098, Val Loss: 1.1181
# Epoch: 135, Train Loss: 1.3967, Val Loss: 1.0337
# Epoch: 136, Train Loss: 1.3458, Val Loss: 1.0796
# Epoch: 137, Train Loss: 1.2267, Val Loss: 1.0262
# Epoch: 138, Train Loss: 1.3511, Val Loss: 0.9796
# Epoch: 139, Train Loss: 1.3406, Val Loss: 1.1489
# Epoch: 140, Train Loss: 1.2904, Val Loss: 1.2980
# Epoch: 141, Train Loss: 1.1904, Val Loss: 1.0567
# Epoch: 142, Train Loss: 1.2088, Val Loss: 0.9873
# Epoch: 143, Train Loss: 1.3291, Val Loss: 1.1109
# Epoch: 144, Train Loss: 1.2620, Val Loss: 1.0876
# Epoch: 145, Train Loss: 1.2991, Val Loss: 1.0506
# Epoch: 146, Train Loss: 1.1757, Val Loss: 0.9888
# Epoch: 147, Train Loss: 1.1988, Val Loss: 1.0653
# Epoch: 148, Train Loss: 1.2327, Val Loss: 1.1068
# Epoch: 149, Train Loss: 1.3006, Val Loss: 1.0315
# Epoch: 150, Train Loss: 1.2406, Val Loss: 1.0357
# Epoch: 151, Train Loss: 1.1968, Val Loss: 0.9640
# Epoch: 152, Train Loss: 1.1926, Val Loss: 1.0392
# Epoch: 153, Train Loss: 1.1681, Val Loss: 0.9198
# Epoch: 154, Train Loss: 1.2304, Val Loss: 1.0941
# Epoch: 155, Train Loss: 1.2914, Val Loss: 1.0015
# Epoch: 156, Train Loss: 1.2797, Val Loss: 1.0298
# Epoch: 157, Train Loss: 1.2059, Val Loss: 1.1975
# Epoch: 158, Train Loss: 1.2834, Val Loss: 1.0306
# Epoch: 159, Train Loss: 1.2102, Val Loss: 0.9914
# Epoch: 160, Train Loss: 1.2986, Val Loss: 1.1379
# Epoch: 161, Train Loss: 1.3460, Val Loss: 1.0348
# Epoch: 162, Train Loss: 1.1480, Val Loss: 1.0396
# Epoch: 163, Train Loss: 1.1531, Val Loss: 1.1448
# Epoch: 164, Train Loss: 1.3127, Val Loss: 1.1009
# Epoch: 165, Train Loss: 1.3743, Val Loss: 1.2271
# Epoch: 166, Train Loss: 1.2254, Val Loss: 1.0305
# Epoch: 167, Train Loss: 1.1713, Val Loss: 1.0196
# Epoch: 168, Train Loss: 1.1362, Val Loss: 1.1684
# Epoch: 169, Train Loss: 1.3951, Val Loss: 1.1372
# Epoch: 170, Train Loss: 1.2994, Val Loss: 1.0661
# Epoch: 171, Train Loss: 1.2186, Val Loss: 1.0567
# Epoch: 172, Train Loss: 1.2538, Val Loss: 1.2893
# Epoch: 173, Train Loss: 1.1974, Val Loss: 0.9320
# Epoch: 174, Train Loss: 1.2624, Val Loss: 0.9453
# Epoch: 175, Train Loss: 1.2569, Val Loss: 1.1529
# Epoch: 176, Train Loss: 1.1824, Val Loss: 0.9855
# Epoch: 177, Train Loss: 1.2140, Val Loss: 1.1646
# Epoch: 178, Train Loss: 1.1507, Val Loss: 1.0042
# Epoch: 179, Train Loss: 1.0962, Val Loss: 1.0410
# Epoch: 180, Train Loss: 1.2452, Val Loss: 1.0252
# Epoch: 181, Train Loss: 1.0899, Val Loss: 1.0461
# Epoch: 182, Train Loss: 1.1576, Val Loss: 1.0962
# Epoch: 183, Train Loss: 1.2403, Val Loss: 1.0478
# Epoch: 184, Train Loss: 1.1017, Val Loss: 1.1276
# Epoch: 185, Train Loss: 1.1133, Val Loss: 1.0691
# Epoch: 186, Train Loss: 1.3234, Val Loss: 1.0087
# Epoch: 187, Train Loss: 1.1419, Val Loss: 1.1801
# Epoch: 188, Train Loss: 1.1525, Val Loss: 1.1872
# Epoch: 189, Train Loss: 1.1537, Val Loss: 1.0044
# Epoch: 190, Train Loss: 1.1681, Val Loss: 1.1642
# Epoch: 191, Train Loss: 1.1868, Val Loss: 0.9788
# Epoch: 192, Train Loss: 1.1389, Val Loss: 1.0798
# Epoch: 193, Train Loss: 1.0971, Val Loss: 0.9515
# Epoch: 194, Train Loss: 1.0898, Val Loss: 1.0553
# Epoch: 195, Train Loss: 1.1467, Val Loss: 1.0979
# Epoch: 196, Train Loss: 1.2210, Val Loss: 1.0564
# Epoch: 197, Train Loss: 1.1037, Val Loss: 1.1588
# Epoch: 198, Train Loss: 1.0759, Val Loss: 0.9857
# Epoch: 199, Train Loss: 1.0279, Val Loss: 0.9507
# Epoch: 200, Train Loss: 1.2197, Val Loss: 0.9420
# Test Loss: 0.9674

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(train_loss_history, label="train")
ax.plot(val_loss_history, label="val")
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.legend()
# ax.set_yscale("log")

# %%
train_preds, train_targets, _ = evaluate(model, train_loader, device)
test_preds, test_targets, _ = evaluate(model, test_loader, device)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(train_targets, train_preds, color="tab:gray", alpha=0.5, label="train", s=20)
ax.scatter(test_targets, test_preds, color="tab:blue", label="test", s=20)
ax.plot([-12,2], [-12,2], color="gray", linewidth=1)
ax.set_xlim(-12, 2)
ax.set_ylim(-12, 2)
ax.set_aspect("equal")
ax.legend()
ax.set_xlabel("logS (true)")
ax.set_ylabel("logS (predict)")
# Out:
# Text(0, 0.5, 'logS (predict)')

# %%
import json
import os
import pickle
import re
from typing import List
from urllib.parse import urljoin

import requests
from bs4 import BeautifulSoup
from langchain.chains import RetrievalQA
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.chat_models import ChatOpenAI
from langchain_community.document_loaders import UnstructuredURLLoader
from langchain_community.embeddings import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

# %%
def get_all_links_with_depth(
    start_url: str, domain_filter: str = "https://docs.lammps.org/", max_depth: int = 2
):
    to_visit = [(start_url, 0)]

    visited = set([start_url])

    all_links = []

    while to_visit:
        current_url, current_depth = to_visit.pop(0)
        all_links.append(current_url)

        if current_depth >= max_depth:
            continue

        try:
            response = requests.get(current_url)
            response.raise_for_status()
        except Exception as e:
            print(f"Error fetching {current_url}: {e}")
            continue

        soup = BeautifulSoup(response.text, "html.parser")
        for link_tag in soup.find_all("a", href=True):
            next_link = urljoin(current_url, link_tag["href"])
            if next_link.startswith(domain_filter) and next_link not in visited:
                visited.add(next_link)
                to_visit.append((next_link, current_depth + 1))

    return all_links

# %%
max_depth = 1
all_links = get_all_links_with_depth(
    start_url="https://docs.lammps.org/Manual.html",
    domain_filter="https://docs.lammps.org/",
    max_depth=max_depth,
)

all_docs = []
for i, link in enumerate(all_links):
    loader = UnstructuredURLLoader(urls=[link])
    try:
        docs = loader.load()
        all_docs.extend(docs)
    except Exception as e:
        print(f"Error loading {link}: {e}")
    print(f"Loaded {i+1}/{len(all_links)}: {link}")
with open("all_docs.pkl", "wb") as f:
    pickle.dump(all_docs, f)
print("all_docs is saved to 'all_docs.pkl'.")
# Out:
# Loaded 1/168: https://docs.lammps.org/Manual.html
# Loaded 2/168: https://docs.lammps.org/Intro.html
# Loaded 3/168: https://docs.lammps.org/Install.html
# Loaded 4/168: https://docs.lammps.org/Build.html
# Loaded 5/168: https://docs.lammps.org/Run_head.html
# Loaded 6/168: https://docs.lammps.org/Commands.html
# Loaded 7/168: https://docs.lammps.org/Packages.html
# Loaded 8/168: https://docs.lammps.org/Speed.html
# Loaded 9/168: https://docs.lammps.org/Howto.html
# Loaded 10/168: https://docs.lammps.org/Examples.html
# Loaded 11/168: https://docs.lammps.org/Tools.html
# Loaded 12/168: https://docs.lammps.org/Errors.html
# Loaded 13/168: https://docs.lammps.org/Library.html
# Loaded 14/168: https://docs.lammps.org/Python_head.html
# Loaded 15/168: https://docs.lammps.org/Modify.html
# Loaded 16/168: https://docs.lammps.org/Developer.html
# Loaded 17/168: https://docs.lammps.org/commands_list.html
# Loaded 18/168: https://docs.lammps.org/fixes.html
# Loaded 19/168: https://docs.lammps.org/computes.html
# Loaded 20/168: https://docs.lammps.org/pairs.html
# Loaded 21/168: https://docs.lammps.org/bonds.html
# Loaded 22/168: https://docs.lammps.org/angles.html
# Loaded 23/168: https://docs.lammps.org/dihedrals.html
# Loaded 24/168: https://docs.lammps.org/impropers.html
# Loaded 25/168: https://docs.lammps.org/dumps.html
# Loaded 26/168: https://docs.lammps.org/fix_modify_atc_commands.html
# Loaded 27/168: https://docs.lammps.org/Bibliography.html
# Loaded 28/168: https://docs.lammps.org/Commands_all.html
# Loaded 29/168: https://docs.lammps.org/Manual.html#lammps-documentation-version-version
# Loaded 30/168: https://docs.lammps.org/Manual.html#about-lammps-and-this-manual
# Loaded 31/168: https://docs.lammps.org/
# Loaded 32/168: https://docs.lammps.org/stable/
# Loaded 33/168: https://docs.lammps.org/latest/
# Loaded 34/168: https://docs.lammps.org/Build_manual.html
# Loaded 35/168: https://docs.lammps.org/Manual.html#webbrowser
# Loaded 36/168: https://docs.lammps.org/Manual.html#user-documentation
# Loaded 37/168: https://docs.lammps.org/Manual.html#programmer-documentation
# Loaded 38/168: https://docs.lammps.org/Manual.html#id1
# Loaded 39/168: https://docs.lammps.org/Manual.html#user-guide
# Loaded 40/168: https://docs.lammps.org/Intro_overview.html
# Loaded 41/168: https://docs.lammps.org/Manual_version.html
# Loaded 42/168: https://docs.lammps.org/Intro_features.html
# Loaded 43/168: https://docs.lammps.org/Intro_nonfeatures.html
# Loaded 44/168: https://docs.lammps.org/Intro_portability.html
# Loaded 45/168: https://docs.lammps.org/Intro_opensource.html
# Loaded 46/168: https://docs.lammps.org/Intro_authors.html
# Loaded 47/168: https://docs.lammps.org/Intro_citing.html
# Loaded 48/168: https://docs.lammps.org/Intro_website.html
# Loaded 49/168: https://docs.lammps.org/Install_linux.html
# Loaded 50/168: https://docs.lammps.org/Install_mac.html
# Loaded 51/168: https://docs.lammps.org/Install_windows.html
# Loaded 52/168: https://docs.lammps.org/Install_conda.html
# Loaded 53/168: https://docs.lammps.org/Install_tarball.html
# Loaded 54/168: https://docs.lammps.org/Install_git.html
# Loaded 55/168: https://docs.lammps.org/Build_cmake.html
# Loaded 56/168: https://docs.lammps.org/Build_make.html
# Loaded 57/168: https://docs.lammps.org/Build_link.html
# Loaded 58/168: https://docs.lammps.org/Build_basics.html
# Loaded 59/168: https://docs.lammps.org/Build_settings.html
# Loaded 60/168: https://docs.lammps.org/Build_package.html
# Loaded 61/168: https://docs.lammps.org/Build_extras.html
# Loaded 62/168: https://docs.lammps.org/Build_windows.html
# Loaded 63/168: https://docs.lammps.org/Build_diskspace.html
# Loaded 64/168: https://docs.lammps.org/Build_development.html
# Loaded 65/168: https://docs.lammps.org/Run_basics.html
# Loaded 66/168: https://docs.lammps.org/Run_options.html
# Loaded 67/168: https://docs.lammps.org/Run_output.html
# Loaded 68/168: https://docs.lammps.org/Run_windows.html
# Loaded 69/168: https://docs.lammps.org/Commands_input.html
# Loaded 70/168: https://docs.lammps.org/Commands_parse.html
# Loaded 71/168: https://docs.lammps.org/Commands_structure.html
# Loaded 72/168: https://docs.lammps.org/Commands_category.html
# Loaded 73/168: https://docs.lammps.org/Commands_fix.html
# Loaded 74/168: https://docs.lammps.org/Commands_compute.html
# Loaded 75/168: https://docs.lammps.org/Commands_pair.html
# Loaded 76/168: https://docs.lammps.org/Commands_bond.html
# Loaded 77/168: https://docs.lammps.org/Commands_bond.html#angle-styles
# Loaded 78/168: https://docs.lammps.org/Commands_bond.html#dihedral-styles
# Loaded 79/168: https://docs.lammps.org/Commands_bond.html#improper-styles
# Loaded 80/168: https://docs.lammps.org/Commands_kspace.html
# Loaded 81/168: https://docs.lammps.org/Commands_dump.html
# Loaded 82/168: https://docs.lammps.org/Commands_removed.html
# Loaded 83/168: https://docs.lammps.org/Packages_list.html
# Loaded 84/168: https://docs.lammps.org/Packages_details.html
# Loaded 85/168: https://docs.lammps.org/Speed_bench.html
# Loaded 86/168: https://docs.lammps.org/Speed_measure.html
# Loaded 87/168: https://docs.lammps.org/Speed_tips.html
# Loaded 88/168: https://docs.lammps.org/Speed_packages.html
# Loaded 89/168: https://docs.lammps.org/Speed_compare.html
# Loaded 90/168: https://docs.lammps.org/Howto.html#general-howto
# Loaded 91/168: https://docs.lammps.org/Howto.html#settings-howto
# Loaded 92/168: https://docs.lammps.org/Howto.html#analysis-howto
# Loaded 93/168: https://docs.lammps.org/Howto.html#force-fields-howto
# Loaded 94/168: https://docs.lammps.org/Howto.html#packages-howto
# Loaded 95/168: https://docs.lammps.org/Howto.html#tutorials-howto
# Loaded 96/168: https://docs.lammps.org/Examples.html#lowercase-directories
# Loaded 97/168: https://docs.lammps.org/Examples.html#uppercase-directories
# Loaded 98/168: https://docs.lammps.org/Tools.html#pre-processing-tools
# Loaded 99/168: https://docs.lammps.org/Tools.html#post-processing-tools
# Loaded 100/168: https://docs.lammps.org/Tools.html#miscellaneous-tools
# Loaded 101/168: https://docs.lammps.org/Tools.html#tool-descriptions
# Loaded 102/168: https://docs.lammps.org/Errors_common.html
# Loaded 103/168: https://docs.lammps.org/Errors_details.html
# Loaded 104/168: https://docs.lammps.org/Errors_bugs.html
# Loaded 105/168: https://docs.lammps.org/Errors_debug.html
# Loaded 106/168: https://docs.lammps.org/Errors_messages.html
# Loaded 107/168: https://docs.lammps.org/Errors_warnings.html
# Loaded 108/168: https://docs.lammps.org/Manual.html#programmer-guide
# Loaded 109/168: https://docs.lammps.org/Library.html#lammps-c-library-api
# Loaded 110/168: https://docs.lammps.org/Library.html#lammps-python-apis
# Loaded 111/168: https://docs.lammps.org/Library.html#lammps-fortran-api
# Loaded 112/168: https://docs.lammps.org/Library.html#lammps-cplusplus-api
# Loaded 113/168: https://docs.lammps.org/Python_overview.html
# Loaded 114/168: https://docs.lammps.org/Python_install.html
# Loaded 115/168: https://docs.lammps.org/Python_run.html
# Loaded 116/168: https://docs.lammps.org/Python_module.html
# Loaded 117/168: https://docs.lammps.org/Python_ext.html
# Loaded 118/168: https://docs.lammps.org/Python_call.html
# Loaded 119/168: https://docs.lammps.org/Python_formats.html
# Loaded 120/168: https://docs.lammps.org/Python_examples.html
# Loaded 121/168: https://docs.lammps.org/Python_error.html
# Loaded 122/168: https://docs.lammps.org/Python_trouble.html
# Loaded 123/168: https://docs.lammps.org/Modify_overview.html
# Loaded 124/168: https://docs.lammps.org/Modify_contribute.html
# Loaded 125/168: https://docs.lammps.org/Modify_requirements.html
# Loaded 126/168: https://docs.lammps.org/Modify_style.html
# Loaded 127/168: https://docs.lammps.org/Modify_atom.html
# Loaded 128/168: https://docs.lammps.org/Modify_pair.html
# Loaded 129/168: https://docs.lammps.org/Modify_bond.html
# Loaded 130/168: https://docs.lammps.org/Modify_compute.html
# Loaded 131/168: https://docs.lammps.org/Modify_fix.html
# Loaded 132/168: https://docs.lammps.org/Modify_command.html
# Loaded 133/168: https://docs.lammps.org/Modify_dump.html
# Loaded 134/168: https://docs.lammps.org/Modify_kspace.html
# Loaded 135/168: https://docs.lammps.org/Modify_min.html
# Loaded 136/168: https://docs.lammps.org/Modify_region.html
# Loaded 137/168: https://docs.lammps.org/Modify_body.html
# Loaded 138/168: https://docs.lammps.org/Modify_gran_sub_mod.html
# Loaded 139/168: https://docs.lammps.org/Modify_thermo.html
# Loaded 140/168: https://docs.lammps.org/Modify_variable.html
# Loaded 141/168: https://docs.lammps.org/Developer_org.html
# Loaded 142/168: https://docs.lammps.org/Developer_org.html#class-topology
# Loaded 143/168: https://docs.lammps.org/Developer_code_design.html
# Loaded 144/168: https://docs.lammps.org/Developer_parallel.html
# Loaded 145/168: https://docs.lammps.org/Developer_atom.html
# Loaded 146/168: https://docs.lammps.org/Developer_comm_ops.html
# Loaded 147/168: https://docs.lammps.org/Developer_flow.html
# Loaded 148/168: https://docs.lammps.org/Developer_write.html
# Loaded 149/168: https://docs.lammps.org/Developer_notes.html
# Loaded 150/168: https://docs.lammps.org/Developer_updating.html
# Loaded 151/168: https://docs.lammps.org/Developer_plugins.html
# Loaded 152/168: https://docs.lammps.org/Developer_unittest.html
# Loaded 153/168: https://docs.lammps.org/Classes.html
# Loaded 154/168: https://docs.lammps.org/Developer_platform.html
# Loaded 155/168: https://docs.lammps.org/Developer_utils.html
# Loaded 156/168: https://docs.lammps.org/Developer_utils.html#special-math-functions
# Loaded 157/168: https://docs.lammps.org/Developer_utils.html#tokenizer-classes
# Loaded 158/168: https://docs.lammps.org/Developer_utils.html#argument-parsing-classes
# Loaded 159/168: https://docs.lammps.org/Developer_utils.html#file-reader-classes
# Loaded 160/168: https://docs.lammps.org/Developer_utils.html#memory-pool-classes
# Loaded 161/168: https://docs.lammps.org/Developer_utils.html#eigensolver-functions
# Loaded 162/168: https://docs.lammps.org/Developer_utils.html#communication-buffer-coding-with-ubuf
# Loaded 163/168: https://docs.lammps.org/Developer_grid.html
# Loaded 164/168: https://docs.lammps.org/Manual.html#command-reference
# Loaded 165/168: https://docs.lammps.org/Manual.html#indices-and-tables
# Loaded 166/168: https://docs.lammps.org/genindex.html
# Loaded 167/168: https://docs.lammps.org/search.html
# Error fetching or processing https://docs.lammps.org/Manual.pdf, exception: partition_pdf() is not available because one or more dependencies are not installed. Use: pip install "unstructured[pdf]" (including quotes) to install the required dependencies
# Loaded 168/168: https://docs.lammps.org/Manual.pdf
# all_docs is saved to 'all_docs.pkl'.

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
split_docs = text_splitter.split_documents(all_docs)

# %%
embeddings = OpenAIEmbeddings(openai_api_key=os.environ["OPENAI_API_KEY"])
vectordb = Chroma.from_documents(
    split_docs,
    embedding=embeddings,
    collection_name="lammps_manual",
    persist_directory="chroma_db",
)

# %%
retriever = vectordb.as_retriever(search_kwargs={"k": 3})
llm = ChatOpenAI(model_name="gpt-4o", openai_api_key=os.environ["OPENAI_API_KEY"])

# %%
qa_chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=retriever)

query = "LAMMPSはどのような分子動力学シミュレーションが可能ですか？"
answer = qa_chain.run(query)
print(answer)
# Out:
# LAMMPSは、液体、固体、気体状態の粒子の集団をモデル化する古典的な分子動力学（MD）コードです。原子、ポリマー、生体分子、固体（金属、セラミック、酸化物）、粒状、粗視化、あるいは巨視的なシステムを、多様な相互原子ポテンシャル（力場）や境界条件を使用してモデル化することができます。2次元または3次元のシステムを数個の粒子から数十億個の粒子までモデル化することが可能です。また、個々の粒子は原子、分子、電子、粗視化された原子群、またはメソスコピックや巨視的な物質の塊であることがあります。
#
# LAMMPSは、並列計算機用に設計されており、MPIメッセージパッシングライブラリをサポートする任意の並列機でシリアルまたは並列で動作します。シェアードメモリのマルチコア、マルチCPUサーバー、および分散メモリクラスターやスーパーコンピューターで実行可能です。LAMMPSの一部はOpenMPマルチスレッド化、ベクトル化、GPUアクセラレーションもサポートしています。

# %%
def score_answers_by_docs(
    evaluator_llm: ChatOpenAI,
    questions: List[str],
    answers: List[str],
    retriever,  # ここで "evaluation_retriever" を想定
    top_k: int = 3,
):
    """
    質問リスト + 回答リストを渡すと、retriever で top_k のドキュメントを取得し、
    LLMに「回答とドキュメントは整合しているか？」をスコアリングさせる
    """
    results = []
    for i, (q, ans) in enumerate(zip(questions, answers)):
        # 関連ドキュメントを取得
        docs = retriever.get_relevant_documents(q)[:top_k]
        doc_texts = "\n\n---\n\n".join(d.page_content for d in docs)

        eval_prompt = f"""
私は、以下の「質問」と「回答」が、参照ドキュメントとどの程度整合しているかを評価します。

【質問】
{q}

【回答】
{ans}

【参照ドキュメント (上位 {top_k} 件)】
{doc_texts}

上記の回答が参照ドキュメントと比較して、どの程度正確・妥当かを1〜5点で評価してください。
1：ほぼ全てが不正確
2：不正確な点が多い
3：おおよそ正しいがいくつか誤り/不足がある
4：ほとんど正確
5：非常に正確・参照ドキュメントと整合

理由の説明は不要なので、数値のみを出力してください。
"""
        eval_response = evaluator_llm.call_as_llm(eval_prompt)

        # スコアの抽出 (雑に数字を拾う)
        match = re.search(r"(\d+)", eval_response)
        if match:
            score = int(match.group(1))
        else:
            score = None

        results.append(
            {"question": q, "answer": ans, "score": score, "eval_raw": eval_response}
        )

    # スコアの平均など
    valid_scores = [r["score"] for r in results if r["score"] is not None]
    avg_score = sum(valid_scores) / len(valid_scores) if valid_scores else 0
    return results, avg_score

# %%
def get_answers(non_rag_llm, rag_chain, questions: List[str]):
    rag_answers = []
    non_rag_answers = []

    for q in questions:
        # RAGなし回答
        non_rag_res = non_rag_llm.call_as_llm(q)
        non_rag_answers.append(non_rag_res)

        # RAGあり回答
        rag_res = rag_chain.run(q)
        rag_answers.append(rag_res)

    return non_rag_answers, rag_answers

# %%
def evaluate_rag_vs_nonrag(
    questions: List[str],
    non_rag_llm: ChatOpenAI,
    rag_chain: RetrievalQA,
    evaluation_retriever,
    evaluator_llm: ChatOpenAI,
    top_k=3,
):
    """
    RAGなし vs RAGあり の回答を取得し、それぞれを評価する。
    """
    # 1. 回答を取得
    non_rag_answers, rag_answers = get_answers(non_rag_llm, rag_chain, questions)

    # 2. RAGなし回答を評価
    print("\n=== Evaluating Non-RAG answers ===")
    non_rag_eval, non_rag_avg = score_answers_by_docs(
        evaluator_llm=evaluator_llm,
        questions=questions,
        answers=non_rag_answers,
        retriever=evaluation_retriever,
        top_k=top_k,
    )
    print(f"Non-RAG Average Score: {non_rag_avg:.2f}")

    # 3. RAGあり回答を評価
    print("\n=== Evaluating RAG answers ===")
    rag_eval, rag_avg = score_answers_by_docs(
        evaluator_llm=evaluator_llm,
        questions=questions,
        answers=rag_answers,
        retriever=evaluation_retriever,
        top_k=top_k,
    )
    print(f"RAG Average Score: {rag_avg:.2f}")

    # 4. 結果比較
    print("\n=== Comparison ===")
    print(f"- Non-RAG Score: {non_rag_avg:.2f}")
    print(f"- RAG Score    : {rag_avg:.2f}")
    improvement = rag_avg - non_rag_avg
    print(f"-> Improvement : {improvement:.2f}")

    # 5. 必要なら JSON などに書き出し
    results_all = {
        "non_rag_eval": non_rag_eval,
        "rag_eval": rag_eval,
        "non_rag_avg": non_rag_avg,
        "rag_avg": rag_avg,
        "improvement": improvement,
    }
    with open("evaluation_rag_vs_nonrag.json", "w", encoding="utf-8") as f:
        json.dump(results_all, f, ensure_ascii=False, indent=2)

    return results_all

# %%
rag_llm = ChatOpenAI(
    model_name="gpt-4o", openai_api_key=os.environ["OPENAI_API_KEY"], temperature=0
)

non_rag_llm = ChatOpenAI(
    model_name="gpt-4o", openai_api_key=os.environ["OPENAI_API_KEY"], temperature=0
)

rag_chain = RetrievalQA.from_chain_type(
    llm=rag_llm,
    chain_type="stuff",
    retriever=retriever,
)

evaluation_retriever = retriever

evaluator_llm = ChatOpenAI(
    model_name="gpt-4o", openai_api_key=os.environ["OPENAI_API_KEY"], temperature=0
)

questions = [
    "LAMMPSはどのような分子動力学シミュレーションが可能ですか？",
    "LAMMPSのインストール方法を教えてください。",
    "LAMMPSのGPUアクセラレーションはどうやって有効にするの？",
]

results = evaluate_rag_vs_nonrag(
    questions=questions,
    non_rag_llm=non_rag_llm,
    rag_chain=rag_chain,
    evaluation_retriever=evaluation_retriever,
    evaluator_llm=evaluator_llm,
    top_k=3,
)
# Out:
# === Evaluating Non-RAG answers ===
# Non-RAG Average Score: 3.33
#
# === Evaluating RAG answers ===
# RAG Average Score: 4.33
#
# === Comparison ===
# - Non-RAG Score: 3.33
# - RAG Score    : 4.33
# -> Improvement : 1.00

# %%
# !git clone https://github.com/JSR-ISM-Smart-Chemistry-Lab/E2T
# Out:
# Cloning into 'E2T'...
# remote: Enumerating objects: 242, done.
# remote: Counting objects: 100% (242/242), done.
# remote: Compressing objects: 100% (175/175), done.
# remote: Total 242 (delta 98), reused 176 (delta 46), pack-reused 0 (from 0)
# Receiving objects: 100% (242/242), 56.09 KiB | 517.00 KiB/s, done.
# Resolving deltas: 100% (98/98), done.

# %%
# !pip install lightning
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.1/821.1 kB 24.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 56.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 47.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 72.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 962.6/962.6 kB 34.3 MB/s eta 0:00:00
# ...

# %%
! pip install learn2learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 34.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 69.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 53.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.1/178.1 kB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.4 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/learnables/learn2learn.git
# %cd learn2learn
# !pip install -e .
# Out:
# Cloning into 'learn2learn'...
# remote: Enumerating objects: 4878, done.
# remote: Counting objects: 100% (1370/1370), done.
# remote: Compressing objects: 100% (610/610), done.
# remote: Total 4878 (delta 769), reused 1170 (delta 626), pack-reused 3508 (from 1)
# Receiving objects: 100% (4878/4878), 9.55 MiB | 13.02 MiB/s, done.
# Resolving deltas: 100% (2774/2774), done.
# /content/learn2learn
# Obtaining file:///content/learn2learn
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached gsutil-5.34-py3-none-any.whl
# ...
#   Using cached argcomplete-3.6.2-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached crcmod-1.7-cp311-cp311-linux_x86_64.whl
# ...
#   Using cached fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached gcs_oauth2_boto_plugin-3.2-py3-none-any.whl
# ...
#   Using cached google_apitools-0.5.32-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached httplib2-0.20.4-py3-none-any.whl.metadata (2.5 kB)
# ...

# %%
# !pip install learn2learn

# %%
! pip install lightning joblib jsonargparse[signatures]
# Out:
# ...
#   Using cached jsonargparse-4.40.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached typeshed_client-2.7.0-py3-none-any.whl.metadata (7.9 kB)
# ...
# Using cached typeshed_client-2.7.0-py3-none-any.whl (624 kB)
# Using cached jsonargparse-4.40.0-py3-none-any.whl (224 kB)
# ...

# %%
# !pip install seaborn joblib jsonargparse[signatures]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.4/624.4 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.3/224.3 kB 11.7 MB/s eta 0:00:00
# ...

# %%
# !cd /content/E2T/ && pip install .
# Out:
# Processing /content/E2T
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for E2T: filename=E2T-0.1.0-py3-none-any.whl size=13596 sha256=ea5efe10780540385dd17b9e060d43cc2b61a48a3beccc7c18951fdf76a89abc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sh8p2e0f/wheels/55/01/e1/6ff0e1e7913472720c4ec8feb7bd27a53c16abd6cf10d564c9
# Successfully built E2T
# ...

# %%
# !pip install rdkit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.9/34.9 MB 25.2 MB/s eta 0:00:00
# ...

# %%
# !cd /content/E2T/examples/RadonPy/00_sample_data_preparation \
&& python prepare_data.py
# Out:
# 2025-06-23 01:32:49,996 - INFO - Load data from PI1070.csv
# 2025-06-23 01:32:50,230 - INFO - Inspect data
# 2025-06-23 01:32:50,246 - INFO - Calculate descriptor
# [01:32:51] DEPRECATION WARNING: please use MorganGenerator
# [01:32:51] DEPRECATION WARNING: please use MorganGenerator
# [01:32:51] DEPRECATION WARNING: please use MorganGenerator
# [01:32:51] DEPRECATION WARNING: please use MorganGenerator
# [01:32:51] DEPRECATION WARNING: please use MorganGenerator
# [01:32:51] DEPRECATION WARNING: please use MorganGenerator
# [01:32:51] DEPRECATION WARNING: please use MorganGenerator
# [01:32:51] DEPRECATION WARNING: please use MorganGenerator
# [01:32:51] DEPRECATION WARNING: please use MorganGenerator
# [01:32:51] DEPRECATION WARNING: please use MorganGenerator
# [01:32:51] DEPRECATION WARNING: please use MorganGenerator
# [01:32:51] DEPRECATION WARNING: please use MorganGenerator
# [01:32:51] DEPRECATION WARNING: please use MorganGenerator
# ...

# %%
# !pip install scikit-learn==1.5.2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 61.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ...

# %%
# !cd /content/E2T/examples/RadonPy/01_domain_generalization/ && python run_experiment.py fit --config sample.yaml
# Out:
# /usr/local/lib/python3.11/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# given by the platformdirs library.  To remove this warning and
# see the appropriate new directories, set the environment variable
# `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# The use of platformdirs will be the default in `jupyter_core` v6
#   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/utilities/seed.py:42: No seed found, seed set to 0
# Seed set to 0
# 2025-06-23 01:42:57,615 [INFO] Output config.yaml
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /content/learn2learn/learn2learn/utils/__init__.py:396: DeprecationWarning: TaskDataset is deprecated, use Taskset instead.
#   warnings.warn(message, category=severity)
#
# ...

# %%
# !cd /content/E2T/examples/RadonPy/02_finetuning && python run_experiment.py
# Out:
# /usr/local/lib/python3.11/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# given by the platformdirs library.  To remove this warning and
# see the appropriate new directories, set the environment variable
# `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# The use of platformdirs will be the default in `jupyter_core` v6
#   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'encoder' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['encoder'])`.
# ...

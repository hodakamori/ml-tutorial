# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/deepchem/deepchem/master/datasets/delaney-processed.csv")
df.head()
# Out:
#   Compound ID  ESOL predicted log solubility in mols per litre  \
# 0   Amigdalin                                           -0.974
# 1    Fenfuram                                           -2.885
# 2      citral                                           -2.579
# 3      Picene                                           -6.618
# 4   Thiophene                                           -2.232
#
#    Minimum Degree  Molecular Weight  Number of H-Bond Donors  Number of Rings  \
# 0               1           457.432                        7                3
# 1               1           201.225                        1                2
# 2               1           152.237                        0                0
# 3               2           278.354                        0                5
# 4               2            84.143                        0                1
#
#    Number of Rotatable Bonds  Polar Surface Area  \
# 0                          7              202.32
# ...

# %%
! mkdir -p ../data

# %%
df.to_csv("../data/delaney-processed.csv", index=False)

# %%
import pandas as pd
df = pd.read_csv(
    "https://raw.githubusercontent.com/MobleyLab/FreeSolv/master/database.txt", sep=";", skiprows=2
)
df.head()
# Out:
#   # compound id (and file prefix)                                   SMILES  \
# 0                  mobley_1017962                             CCCCCC(=O)OC
# 1                  mobley_1019269                                    CCCCO
# 2                  mobley_1034539   c1cc(c(cc1c2cc(c(c(c2Cl)Cl)Cl)Cl)Cl)Cl
# 3                  mobley_1036761                              C1CCC(CC1)N
# 4                  mobley_1046331                           c1ccc(cc1)OC=O
#
#    iupac name (or alternative if IUPAC is unavailable or not parseable by OEChem)  \
# 0                                   methyl hexanoate
# 1                                         butan-1-ol
# 2   1,2,3,4-tetrachloro-5-(3,4-dichlorophenyl)ben...
# 3                                    cyclohexanamine
# 4                                     phenyl formate
#
#     experimental value (kcal/mol)   experimental uncertainty (kcal/mol)  \
# 0                           -2.49                                   0.6
# ...

# %%
df.to_csv("../data/freesolv.csv", index=False)
